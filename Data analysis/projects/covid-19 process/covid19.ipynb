# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corona = pd.read_csv(r"./covid19_Confirmed_dataset.csv")
corona.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %% [markdown]
# data is imported and ready to go, next ill take a look at the data and do a little bit of preprossing/

# %%
corona.shape
# Out:
# (266, 104)

# %%
corona.drop(columns=["Lat","Long"],axis=1, inplace=True)

# %%
corona.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
newcorona = corona.groupby("Country/Region").sum()

# %%
newcorona.head()
# Out:
#                Province/State  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Afghanistan                 0        0        0        0        0        0
# Albania                     0        0        0        0        0        0
# Algeria                     0        0        0        0        0        0
# Andorra                     0        0        0        0        0        0
# Angola                      0        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  1/30/20  ...  4/21/20  4/22/20  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...     1092     1176
# Albania               0        0        0        0  ...      609      634
# Algeria               0        0        0        0  ...     2811     2910
# Andorra               0        0        0        0  ...      717      723
# ...

# %%
newcorona.shape
# Out:
# (187, 101)

# %% [markdown]
# 187 countries and 101 dates

# %%
newcorona.loc['Egypt'].plot()
plt.legend()

# %%
newcorona.loc['Egypt'].diff().plot()
# Out:
# <Axes: >

# %% [markdown]
# this shows infection rate in egypt till 30-4-20

# %%
newcorona.loc['Egypt'].diff().max()
# Out:
# 269

# %% [markdown]
# topped at 269 patients

# %%
newcorona = newcorona.apply(pd.to_numeric, errors='coerce')
newcorona = newcorona.fillna(0)

# %%
countries = list(newcorona.index)
max_infection_rates = []
for c in countries:
    max_infection_rates.append(newcorona.loc[c].diff().max())
newcorona["max_infection_rate"] = max_infection_rates

# %%
corona_data = pd.DataFrame(newcorona["max_infection_rate"])
corona_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %%
happy = pd.read_csv(r"./worldwide_happiness_report.csv")
happy.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
useless = ["Overall rank","Score", "Generosity","Perceptions of corruption"]

happy.drop(useless, axis=1, inplace=True)
happy.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
newhappy = happy.groupby("Country or region").sum()
newhappy.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Afghanistan                 0.350           0.517                    0.361
# Albania                     0.947           0.848                    0.874
# Algeria                     1.002           1.160                    0.785
# Argentina                   1.092           1.432                    0.881
# Armenia                     0.850           1.055                    0.815
#
#                    Freedom to make life choices
# Country or region
# Afghanistan                               0.000
# Albania                                   0.383
# Algeria                                   0.086
# Argentina                                 0.471
# Armenia                                   0.283

# %%
final = corona_data.join(newhappy, how="inner")
final.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
final.corr()
# Out:
#                               max_infection_rate  GDP per capita  \
# max_infection_rate                      1.000000        0.250118
# GDP per capita                          0.250118        1.000000
# Social support                          0.191958        0.759468
# Healthy life expectancy                 0.289263        0.863062
# Freedom to make life choices            0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infection_rate                  0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# max_infection_rate                                0.078196
# ...

# %%
x= final["GDP per capita"]
y= final["max_infection_rate"]
sns.scatterplot(x=x, y=np.log(y))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='max_infection_rate'>

# %% [markdown]
# what does this prove?
# it proves that the more the country is developed the more its prone to get infected by corono

# %% [markdown]
# or does it ?
# so i got another dataset to see if thats the case.
# its a dataset about the deathcases realted to corona virus.

# %%
deaths = pd.read_csv(r"./covid19_deaths_dataset.csv")
deaths.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...       36       40       42       43
# 1        0        0        0  ...       26       27       27       27
# 2        0        0        0  ...      392      402      407      415
# 3        0        0        0  ...       37       37       37       40
# 4        0        0        0  ...        2        2        2        2
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %% [markdown]
# ill do the same thing i did with first dataset

# %%
useless = ["Lat","Long"]

deaths.drop(useless, axis=1, inplace=True)
deaths.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...       36       40       42       43
# 1        0        0        0  ...       26       27       27       27
# 2        0        0        0  ...      392      402      407      415
# 3        0        0        0  ...       37       37       37       40
# 4        0        0        0  ...        2        2        2        2
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
newdeaths = deaths.groupby("Country/Region").sum()
newdeaths.head()
# Out:
#                Province/State  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Afghanistan                 0        0        0        0        0        0
# Albania                     0        0        0        0        0        0
# Algeria                     0        0        0        0        0        0
# Andorra                     0        0        0        0        0        0
# Angola                      0        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  1/30/20  ...  4/21/20  4/22/20  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...       36       40
# Albania               0        0        0        0  ...       26       27
# Algeria               0        0        0        0  ...      392      402
# Andorra               0        0        0        0  ...       37       37
# ...

# %%
newdeaths.shape
# Out:
# (187, 101)

# %%
newdeaths.loc['Egypt'].plot()
plt.legend()

# %%
newdeaths = newdeaths.apply(pd.to_numeric, errors='coerce')
newdeaths = newdeaths.fillna(0)

# %%
countries = list(newdeaths.index)
max_deaths_rates = []

for c in countries:
    max_deaths_rates.append(newdeaths.loc[c].diff().max())

newdeaths["max_deaths_rate"] = max_deaths_rates

# %%
newdeaths.head()
# Out:
#                 Province/State  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Afghanistan                0.0        0        0        0        0        0
# Albania                    0.0        0        0        0        0        0
# Algeria                    0.0        0        0        0        0        0
# Andorra                    0.0        0        0        0        0        0
# Angola                     0.0        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  1/30/20  ...  4/22/20  4/23/20  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...       40       42
# Albania               0        0        0        0  ...       27       27
# Algeria               0        0        0        0  ...      402      407
# Andorra               0        0        0        0  ...       37       37
# ...

# %%
max_deaths = pd.DataFrame(newdeaths["max_deaths_rate"])
max_deaths.head()
final_data = max_deaths.join(newhappy, how="inner")
final_data.head()
# Out:
#              max_deaths_rate  GDP per capita  Social support  \
# Afghanistan              7.0           0.350           0.517
# Albania                  4.0           0.947           0.848
# Algeria                 30.0           1.002           1.160
# Argentina               13.0           1.092           1.432
# Armenia                  3.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
x = final_data["GDP per capita"]
y = final_data["max_deaths_rate"]
plt.scatter(x= x , y= np.log(y))
plt.show()
# Out:
# c:\Python312\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# this doubles down on my question above, the answers is YES the more the developed a country is the more it is prone to covid , not due to insufficenet tests of covid taken in less develped contries.
# Ty
